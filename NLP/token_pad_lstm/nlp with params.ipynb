# %% [markdown]
# ### Import packages

# %%
import pandas as pd
import numpy as np
import string
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")
warnings.simplefilter(action='ignore', category=FutureWarning)
# set seeds for reproducability
from tensorflow.keras.utils import set_random_seed
from numpy.random import seed
set_random_seed(2)
seed(1)
# keras module for building LSTM 
from keras.models import Model
from keras.utils import pad_sequences
from keras.layers import Embedding, LSTM, Dense, Dropout, Input, Concatenate
from keras.preprocessing.text import Tokenizer
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from sklearn.model_selection import train_test_split
import keras.utils as ku

import pickle
# Out:
# 2023-04-11 18:34:44.211423: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-11 18:34:45.292636: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/pardalito/miniconda3/envs/meia/lib/
# 2023-04-11 18:34:45.292793: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/pardalito/miniconda3/envs/meia/lib/
# 2023-04-11 18:34:45.292808: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ### Read corpus

# %%
data = pd.read_csv('./nlp_data.csv')
#files = []
#for file in data['filename']:
#    with open('../corpus/'+file) as f:
#        content = f.read()
#    files.append(content)

#data = data.assign(reports=files)

report = data['report']
data = data.drop('report',axis = 1)

# %% [markdown]
# #### Clean Text

# %%
def clean_text(txt):
    txt = "".join(t for t in txt if t not in string.punctuation).lower()
    txt = txt.encode("utf8").decode("ascii",'ignore')
    return txt  

corpus = [clean_text(x) for x in report]

# %%
corpus
# Out:
# ['report for solar power predictions for ema  october 7th 2023  1500 hours\n\nbased on our predictions the solar power generated by your solar panels at 1500 hours on october 7th 2023 will be high the predicted value is 10143 kilo watts\n\nthis high power generation can be attributed to the positive contribution of dewpoint therefore you can use your dishwasher and air conditioner without worrying about exceeding the generated power\n\nhowever it is important to note that the appliance water heater will definitely exceed the generated power therefore we recommend minimizing its usage during this time\n\nthank you\n\nbest regards\ntenergito',
#  'dear ana\n\nwe hope this message finds you well as one of our valued solar panel clients we want to keep you informed about the predicted solar power that will be generated from your panels\n\naccording to our analysis on june 8th 2023 at 400 pm you can expect a medium amount of solar power to be generated with a predicted value of 28 kilo watts however we would like to inform you that this prediction is affected by the current temperature which is expected to have a negative impact\n\nwe recommend that you use your heater during this time as it will not exceed the generated power however we caution against using your washing machine as it might exceed the generated power additionally your air conditioner will definitely surpass the generated power so we advise against using it during this time\n\nwe hope this report helps you plan your energy usage and make the most of the solar power generated by your panels as always please do not hesitate to contact us if you have any questions or concerns\n\nsincerely\n\ntenergito',
#  'dear ema\n\nwe hope this letter finds you well we are delighted to inform you that on february 27th 2023 at 2 pm your solar panels are estimated to generate 9429 kilo watts of power this predicted high power generation is due to the positive contribution of the dewpoint and temperature predicted values\n\nthis high power generation enables you to utilize your household appliances such as the heater dishwasher and washing machine without exceeding the generated power with the predicted high solar power generation you can comfortably use your appliances without worrying about power outages or exceeding your power generation capabilities\n\nwe are committed to providing you with accurate and timely solar power generation predictions to help you utilize the full potential of your solar panels if you have any questions or concerns please do not hesitate to contact us\n\nsincerely\ntenergito',
#  'dear ana\n\ni am pleased to present you with a small report on the predicted solar power generation from your solar panels on november 28th 2023 at 1500 \n\nbased on our analysis the solar power generated at that time is expected to be very high at 13857 kilo watts this is due to the solar radiation predicted value having a significant positive contribution \n\nyou should be able to use your water heater washing machine and dishwasher without exceeding the generated power however we recommend that you avoid using your air conditioner at this time as it might exceed the generated power\n\nplease let us know if you have any further questions or concerns\n\nbest regards\n\ntenergito',
#  'dear diana\n\nwe hope this message finds you well we wanted to provide you with a report on the predicted solar power generation from your solar panels on april 6th 2024 at 6 oclock according to our projections the solar power generated during this time will be low at around 3429 kilo watts\n\nthis low power generation is due to several factors including the predicted solar radiation having a negative impact as well as an anticipated significant negative impact from hourly precipitation\n\nwhile this may impact the amount of power available for your daily activities we wanted to provide you with some guidance to make the most of your generated solar power based on our projections we recommend caution when using appliances such as air conditioners which will likely exceed the generated power on the other hand based on our calculations you can safely use appliances such as dishwashers without surpassing the generated power limit\n\nwe hope this report helps inform your energy usage as you continue to utilize your solar panels if you have any further questions please dont hesitate to reach out\n\nbest\ntenergito',
#  'dear ana\n\nwe hope this message finds you well we wanted to update you on the solar power generated from your solar panels on october 26th 2023 at 14oclock\n\nunfortunately due to the hourly precipitation predicted value the solar power generated was medium at 3733 kilo watts we understand that you were hoping for more power but please know that we are constantly monitoring and adjusting the system to ensure the best possible results\n\nadditionally we wanted to inform you that your washing machine and water heater are likely to exceed the generated power we recommend that you try to limit their use during this time to avoid any potential power issues\n\nif you have any further questions or concerns please do not hesitate to reach out to us we appreciate your partnership and look forward to continuing our work together\n\nbest regards\n\ntenergito',
#  'dear carlos\n\nwe hope this message finds you well we have generated a report for you regarding the predicted solar power generated from your solar panels on april 14th 2024 at 11 oclock according to our analysis the solar power generated on this day is expected to be exceptionally high at 328 kilo watts\n\nthis high level of solar power generation can be attributed to the predicted solar radiation value which has a significant positive contribution as well as the temperature predicted value which also has a positive contribution\n\nwe are pleased to inform you that given this level of solar power generation you will be able to use your heater washing machine and air conditioner without surpassing the generated power\n\nwe hope you find this information useful and look forward to providing you with further reports in the future\n\nbest regards\n\ntenergito',
#  'dear ema\n\nwe are pleased to inform you that the solar power generated by your solar panels on june 14th 2023 at 200 pm will be high at 248 kilo watts this is due to the dew point predicted value having a positive contribution and the solar radiation predicted value also having a positive contribution\n\ngiven this high level of generated power you are free to use your heater and dishwasher without exceeding the amount of power generated by your solar panels\n\nwe hope this information is helpful to you and please dont hesitate to contact us if you have any additional questions or concerns\n\nbest regards\n\ntenergito',
#  'dear ema\n\nwe hope this message finds you well as your solar power provider we are excited to share with you the solar power prediction for january 1st 2024 at 15 oclock based on our analysis we predict that your solar panels will generate a high amount of power specifically 272 kilo watts this is due to the positive contribution of the temperature predicted value\n\nwe know that having this information can help you plan your energy consumption better according to our analysis you can use your air conditioner and heater without exceeding the generated power however we advise that you be cautious with your washing machine as it may exert more power than is generated\n\nadditionally we recommend that you avoid using your dishwasher at this time as it will definitely exceed the generated power please note that this prediction is based on current weather patterns and may change based on unforeseen events\n\nwe hope you find this information helpful in managing your energy consumption if you have any questions or concerns please do not hesitate to contact us\n\nbest regards\ntenergito',
#  'yes here is a small report for your client ema with the information provided\n\nreport for solar power generated on july 6th 2023 at 1900 for client ema \n\ndear ema \n\nwe are providing you with an update on the solar power generated by your solar panels on july 6th 2023 at 1900 based on the solar radiation predicted value it is expected that the solar power generated will be very low at 0714 kilo watts this is due to the negative impact of solar radiation on that particular day and time \n\nwe would like to inform you that based on this prediction it is expected that the solar power generated will not be sufficient to meet the energy demands of your appliances specifically your heater will exceed the generated power therefore we recommend that you consider alternative sources of power for your appliances during this time \n\nplease note that the solar radiation predictions can sometimes be subject to change and we will keep you updated in case of any changes \n\nif you have any questions or concerns please do not hesitate to contact us \n\nsincerely\ntenergito',
#  'dear ana\n\nwe have generated a solar power prediction report for your solar panels for february 16th 2023 at 9 oclock unfortunately due to predicted low solar radiation values the generated solar power will be very low at 1133 kilo watts \n\nwe would like to inform you that this means that some of your appliances might exceed the generated power particularly your water heater washing machine air conditioner and dishwasher we recommend that you take measures to reduce the energy consumption of these appliances during this time\n\nplease let us know if you have any questions or concerns about this report \n\nthank you\ntenergito',
#  'dear ricardo\n\nwe hope this message finds you well we are writing to provide you with a brief report on the predicted solar power generation from your solar panels on december 17th 2023 at 8 oclock\n\nbased on the solar radiation predicted value we anticipate that the solar power generated will be very low at approximately 016 kilo watts unfortunately this means that some of your appliances may exceed the generated power including your washing machine dishwasher and air conditioner\n\nas such we advise that you keep an eye on the performance of these appliances during this period to ensure that they are not drawing too much power from the grid if possible we recommend adjusting their usage times to coincide with periods of higher solar power generation to maximize the benefit of your solar panels\n\nthank you for your continued partnership with us please dont hesitate to contact us if you have any further questions or concerns\n\nbest regards\n\ntenergito',
#  'dear diana\n\ni am writing to provide you with a report on the solar power generated by your solar panels on november 13th 2024 at 11oclock according to our predictions the solar power generated will be medium with a capacity of 3267 kilo watts this is due to the temperature predicted value which has a negative impact on the solar panels performance\n\nbased on this information we suggest that you use the dishwasher as it wont surpass the generated power however we advise that you avoid using the air conditioner as it might exceed the generated power thus affecting your electricity bills additionally its important to note that your washing machine will definitely exceed the generated power\n\nwe understand that solar power is an important part of your savings plan and were here to help you make the most of your investment our team of experts is available to answer any questions you may have and provide you with additional reports and insights that can help you optimize your solar panels performance\n\nthank you for entrusting us with your solar power needs and we look forward to continuing to serve you\n\nsincerely\n\ntenergito',
#  'dear carlos\n\ni hope this message finds you well as your solar power provider we wanted to provide you with a report on the predicted solar power generation on march 9th 2024 at 1800 according to our analysis the solar radiation predicted value for that time and date will be high and we expect your solar panels to generate approximately 4867 kilo watts of power\n\nbased on this prediction we wanted to provide you with some guidance on the use of your household appliances it is safe to use your washing machine and water heater during this time as they will not surpass the generated power however we advise caution when it comes to using the appliances heater as it may exceed the generated power\n\nunfortunately we must inform you that using your dishwasher during this time will definitely exceed the generated power therefore we recommend avoiding the use of your dishwasher during this time to prevent interruptions to your power supply\n\nwe hope you find this information informative and helpful as always please do not hesitate to reach out to us if you have any further questions or concerns\n\nbest regards\ntenergito',
#  'dear ricardo\n\ni hope this message finds you well as you know we monitor and predict the solar power generated by your solar panels we wanted to notify you of an upcoming event on june 26th 2024 at 19oclock on this day we predict that the solar power generated will be very low at 004 kilo watts this is due to the solar radiation predicted value having a significant negative impact\n\nwe wanted to bring this to your attention because your appliances may be affected by this decrease in solar power specifically your appliances heater may exceed the generated power and your water heater and washing machine will definitely exceed the generated power\n\nwe recommend that you plan accordingly and consider reducing your energy consumption during this time if you have any questions or concerns please dont hesitate to reach out\n\nthank you for trusting us to monitor your solar power generation\n\nbest regards\n\ntenergito',
#  'dear ema\n\nwe are pleased to inform you that according to our solar power predictions on march 6th 2023 at 14 oclock you can expect to generate a high amount of solar power the predicted value is 100 kilo watts which is attributed to positive temperature conditions at that time of the day\n\nthis means that you will have sufficient solar power to use your water heater heater and washing machine without surpassing the generated power you can use these appliances without worrying about extra energy costs\n\nwe hope you find this information helpful and we look forward to providing you with more updates on your solar power generation in the future\n\nbest regards\ntenergito',
#  'dear toms\n\nwe would like to provide you with a small report regarding the solar power generated from your solar panels on february 21st 2024 at 8 oclock\n\nunfortunately due to the predicted solar radiation value having a negative impact the generated solar power is predicted to be low at approximately 40 kilo watts while this may not be ideal we want to ensure that you are aware of the impact it may have on your home appliances\n\nfirstly we have determined that you can safely use your dishwasher as it will not surpass the generated power however we must caution you that using your air conditioner at this time may exceed the generated power from your solar panels\n\nfinally your washing machine and water heater are both predicted to exceed the generated power from your solar panels we highly recommend that you adjust your usage of these appliances accordingly to avoid any potential issues\n\nwe hope that this information is helpful in managing your usage of home appliances and ensuring that you are making the most out of your solar power generation\n\nbest regards\ntenergito',
#  'report for client ema  february 7th 2024 1300\n\ndear ema\n\nwe hope this report finds you well our team at tenergito has analyzed the solar power predictions from your solar panels for february 7th 2024 at 1300 based on our analysis we estimate that your solar panels will generate a medium amount of power 80 kilowatts\n\nwe wanted to inform you that the hourly precipitation predicted value and the temperature predicted value have a negative impact on the solar power generated as a result we recommend using appliances that will not surpass the generated power such as the washing machine and water heater\n\nhowever we advise against using appliances such as the air conditioner and dishwasher as they will exceed the generated power it is important to be cautious when using appliances that might exceed the generated power such as the appliances heater\n\nplease let us know if you have any questions or concerns regarding the information provided above we take pride in providing efficient reliable and accurate solar power predictions to our clients\n\nbest regards\n\ntenergito',
#  'dear diana\n\nwe hope this finds you well we wanted to provide you with an update on your solar power generation for january 21st 2023 at 8 oclock\n\nour predictive models indicate that due to the expected precipitation during this time the solar power generated from your panels might be low estimated to be around 16 kilo watts we wanted to inform you that this could have an impact on the use of your household appliances\n\nplease note that if you plan to run your washing machine during this time it is possible that it might exceed the generated power on the other hand your heater will definitely exceed the generated power during this time\n\nwe hope that this information is helpful for you as you navigate your energy usage during this time if you have any further questions or concerns please do not hesitate to reach out to us\n\nthank you for choosing our services\n\nbest regards \ntenergito',
#  'dear ema\n\nwe hope this finds you well as your solar power provider we wanted to update you on the predicted solar power generation for may 16th 2024 at 1900\n\nunfortunately based on the solar radiation predicted value we anticipate a very low power output of 1067 kilo watts we wanted to advise you that this may result in challenges powering your appliances\n\nspecifically your heater may exceed the generated power while your dishwasher water heater and air conditioner will definitely exceed the generated power we recommend taking this into consideration for your energy usage during this time\n\nplease let us know if you have any questions or concerns and we will be happy to assist you further\n\nbest\ntenergito',
#  'dear toms\n\nwe are pleased to provide you with a solar power prediction report for may 14th 2023 at 10 oclock the solar panels installed at your property are predicted to generate a high amount of power specifically 50 kilo watts\n\nthis increase in solar power is due to the temperature predicted value and dewpoint predicted value having a positive contribution with this level of solar power generation we are confident that you will be able to use your water heater and heater without any issues\n\nhowever we do advise that you refrain from using your washing machine during this time as it is predicted to exceed the generated power which could result in issues with overloading\n\nplease do not hesitate to contact us if you have any questions or concerns\n\nthank you for choosing us for your solar power needs\n\nbest regards \ntenergito',
#  'date september 19th 2023\n\nsubject solar power report for september 19th 2023\n\ndear rafael\n\nwe hope this letter finds you well as part of our commitment to providing you with quality solar energy services we have generated a small report based on the solar power predictions for september 19th 2023 specifically at 2000 hours \n\nwe regret to inform you that on this particular day the solar power generated will be very low 0867 kilo watts due to solar radiation predicted value having a significant negative impact unfortunately based on our analysis the generated power will not be sufficient for your appliances heater washing machine and dishwasher which will exceed the generated power\n\nwe understand how important it is for you to receive adequate solar power for your household needs therefore we recommend that you use alternative energy sources or consider adjusting your usage patterns during these particular periods with low solar radiation to avoid additional expenses \n\nif you have any concerns or questions about this report please do not hesitate to contact us at any time\n\nthank you for choosing us as your solar energy provider\n\nsincerely\ntenergito',
#  'dear toms\n\nwe wanted to provide you with an update regarding the solar power generated by your solar panels on january 18th 2024 at 1900 we predict that the solar radiation will have a significantly negative impact on your panels performance resulting in a low power generation of only 0067 kilowatts\n\nplease note that during this time your air conditioner may exceed the generated power which means that you may need to rely on your usual energy source to power it your water heater and dishwasher are also expected to exceed the generated power which means that you may need to schedule their usage for a time when the panels are generating more power\n\nif you have any questions or concerns please do not hesitate to reach out to us\n\nbest regards\n\ntenergito',
#  'dear ana\n\nwe hope this email finds you well we wanted to provide you with a quick update on the predicted solar power generation from your solar panels on may 21st 2024 at 1300\n\nwe expect the solar power generated to be medium with an estimated output of 6286 kilo watts during this time we predict that the temperature will have a negative impact on the generated power it is important to note that this might lead to difficulties in running some of your appliances particularly your heater water heater and dishwasher as they require more power than what will be generated\n\nto ensure that you make the best use of the power generated and avoid any power outages or issues running your appliances we recommend conserving power during this timeframe you may want to consider rescheduling your appliance usage until a more optimal time when solar power generation is sufficient\n\nthank you for choosing our services and please dont hesitate to reach out to us if you have any further questions or concerns\n\nbest regards\ntenergito',
#  'solar power prediction report for ema  october 14th 2024\n\ndate october 14th 2024\ntime 1300\n\nsolar power generated medium 6714 kw\n\nexplanation\nbased on our solar power prediction model we anticipate that on october 14th 2024 at 100 pm the solar panels installed at your home will generate a medium amount of power equal to 6714 kilo watts kw\n\nthis prediction is mainly influenced by the temperature predicted for that time which we expect to have a negative impact on solar power generation\n\nimpact on home appliances\nwith this amount of solar power you should be able to use your heater normally as it wont exceed the generated power however if youre planning to use the dishwasher you might exceed the generated power and you might want to consider adjusting your consumption habits during this period\n\nplease note that our solar power prediction model is based on multiple factors including weather forecasts historical data and other variables while we strive to provide accurate predictions these are subject to change based on unforeseen circumstances\n\nif you have any questions or concerns about your solar power generation please dont hesitate to contact us\n\nbest regards\ntenergito',
#  'dear toms\n\nas your solar energy provider we wanted to share with you the predicted solar power output for september 14th 2023 at 2000 unfortunately we anticipate that the solar radiation will be low on this day affecting the amount of solar energy generated by your panels we expect a solar power output of 2714 kilo watts during this time\n\nwe also want to remind you that your appliances namely your dishwasher and air conditioner are expected to exceed the generated solar power on this day we recommend that you conserve energy as much as possible to avoid any additional costs\n\nif you have any questions or concerns please do not hesitate to reach out to us\n\nthank you for choosing us as your solar energy provider\n\nbest regards\ntenergito',
#  'dear ricardo\n\nwe are pleased to provide you with a solar power prediction report for may 23rd 2024 at 600 am at this time the predicted solar power generation from your solar panels is expected to be high at 26 kilo watts this is due to the positive contribution from the temperature predicted value\n\nwe would like to inform you that based on this prediction you can use your air conditioner and dishwasher without exceeding the generated power however we recommend that you avoid using any appliances that consume high power such as the heater as it will likely exceed the generated power\n\nwe hope this report helps you plan your energy consumption efficiently and maximize the usage of your solar power please feel free to contact us for any further assistance\n\nbest regards\n\ntenergito',
#  'dear diana\n\nwe hope this report finds you well we wanted to update you on the solar power predictions for your solar panels for july 28th 2023 at 17oclock\n\nunfortunately we predict low solar power generation at 116 kilo watts due to the predicted hourly precipitation having a significant negative impact however we suggest using the water heater as it wont surpass the generated power\n\non the other hand we advise against using the air conditioner and washing machine as they will definitely exceed the generated power\n\nplease let us know if you have any further questions or concerns we are always here to support you in optimizing your solar power generation\n\nbest regards\n\ntenergito',
#  'dear toms\n\nwe hope this message finds you well as your solar power provider we wanted to provide you with some important information regarding the solar power generated on october 22nd 2024 at 20oclock \n\naccording to our solar power predictions the amount of solar power generated on this day will be very low estimated at only 04 kilo watts this decrease in solar radiation is predicted to have a significant negative impact on the amount of solar power your panels generate \n\nwe wanted to inform you that due to the low solar power generation your household appliance usage may have an impact on your energy consumption specifically your heaters water heater air conditioner and washing machine will likely exceed the amount of solar power generated on this day \n\ntherefore we recommend that you take measures to limit the usage of these appliances or consider using them at times when solar radiation is high in order to minimize the impact on your energy consumption \n\nif you have any questions or concerns please do not hesitate to reach out to us we are committed to providing you with the best possible service and ensuring that your solar power system meets your energy needs\n\nbest regards \ntenergito',
#  'dear ana\n\ni hope this message finds you well i wanted to provide you with a quick update on your solar power predictions according to our analysis on february 23rd 2023 at 10 oclock your solar panels are expected to generate a medium amount of power estimated at 60 kilo watts\n\nhowever we wanted to make you aware that this prediction may be impacted by the hourly precipitation forecast as there is a chance for rain during this time it could have a negative impact on the amount of power generated nonetheless you should still be able to use your air conditioner since it will not exceed your predicted power output\n\nas always please dont hesitate to reach out if you have any further questions or concerns thank you for your continued partnership\n\nbest regards\ntenergito',
#  'dear carlos\n\nwe hope this message finds you well as your solar power consultant we wanted to update you on the solar power predictions for your panels on january 15th 2024 at 6 oclock\n\nbased on our analysis the solar power generated during that time will be low at 4857 kilo watts this is due to the predicted hourly precipitation which had a significant negative impact on the solar radiation predicted value\n\nwe also want to advise you that your washing machine is predicted to exceed the amount of generated power during that time frame we recommend running your washing machine during a time when solar power production is at a higher level\n\nif you have any questions or concerns please do not hesitate to contact us we are always here to help you make the most out of your solar panels\n\nbest regards\n\ntenergito',
#  'dear diana\n\ni hope this message finds you well as your solar power consultant i am sending you a report with the solar power predictions for november 29th 2024 at 9 oclock\n\nit is expected that on this day the solar panels will generate a high amount of power specifically 4267 kilo watts this is due to the predicted temperature value that will have a positive impact on the solar power generation\n\nbased on this prediction you should be able to use your water heater and air conditioner without any issues as they will not surpass the generated power however please note that your dishwasher might exceed the generated power and may cause a power interruption therefore i recommend using this appliance when the solar power is not at its peak\n\nfinally the washing machine will definitely exceed the generated power so i advise you to use it during the day but not at peak hours to avoid any inconvenience\n\ni hope this information is helpful to you and i remain at your disposal should you have any further questions or concerns\n\nsincerely\n\ntenergito',
#  'dear ricardo\n\ni hope this message finds you well i am writing to provide you with a solar power generation report for may 5th 2024 at 1600 according to our systems predictions the solar power generated will be high at 5133 kilo watts\n\nthis is due to the solar radiation predicted value having a positive contribution and the dew point predicted value also having a positive contribution as a result you can use your washing machine air conditioner and dishwasher without exceeding the generated power\n\nhowever please note that your appliances heater might exceed the generated power additionally your appliances water heater will definitely exceed the generated power\n\nthank you for choosing our company for your solar needs if you have any questions or concerns please do not hesitate to contact me\n\nbest regards\n\ntenergito',
#  'dear toms\n\nwe hope this message finds you well as you know we monitor the solar power generated by your solar panels on a regular basis we would like to inform you that on december 13rd 2024 at 7 oclock the solar power generated will be medium 216 kilowatts\n\nthis is due to the hourly precipitation predicted value and temperature predicted value having a negative impact on the generation however you can still use the dishwasher and water heater without surpassing the generated power unfortunately the washing machine will definitely exceed the generated power\n\nwe hope you find this information useful and please do not hesitate to contact us if you have any further questions or concerns\n\nbest regards\n\ntenergito',
#  'dear toms\n\nwe hope this email finds you well as your solar power consultant we have generated a report predicting the amount of solar power that will be generated by your solar panels on june 21st 2024 at 1600\n\nwe are pleased to inform you that at the given time the solar power generated will be high with a predicted value of 312 kilo watts this high value is due to the positive contribution of the temperature predicted value\n\nwe would like to remind you that with the high solar power generated you can utilize your water heater without any issues however we advise you against using your dishwasher as it will definitely exceed the generated power\n\nshould you need further assistance please dont hesitate to contact us at any time we are always here to assist you with any queries you may have\n\nbest regards\n\ntenergito',
#  '\n\nsolar power prediction report for ana  august 12nd 2023 1200 pm\n\ndear ana\n\nwe have generated a solar power prediction report for you based on the data collected from your solar panels on august 12nd 2023 at 1200 pm here are the details\n\ngenerated power 5667 kw\n\ntemperature 85f\n\nappliances usable\n\n heater\n water heater\n air conditioner\n\nappliances not usable\n\n dishwasher\n\nthe solar power generated by your solar panels at this time is predicted to be very high which means you can use your heater water heater and air conditioner without any issues however your dishwasher might exceed the generated power so it is recommended to avoid using it during this time\n\nplease note that the predicted values may not be accurate due to various factors such as weather conditions panel efficiency and maintenance however we have tried our best to provide you with the most reliable prediction based on the available data\n\nif you have any further questions or concerns please do not hesitate to contact us\n\nsincerely\n\ntenergito',
#  'yes here is a sample report\n\ndear toms\n\ni hope this message finds you well as your solar power specialist i wanted to share with you some information about the solar power generated by your solar panels\n\non july 24th 2023 at 1800 we predict that your solar panels will generate medium solar power levels of approximately 7571 kilo watts however we also want to let you know that there are a few factors that may have a negative impact on the solar power generated during this time \n\nfirstly the temperature predicted value is expected to be quite high on this day which may impact the efficiency of your solar panels additionally we are also forecasted to experience a slight rainfall during this time which may also contribute to lower energy production\n\nplease keep in mind that your appliances particularly the water heater may exceed the generated power during this time we recommend taking precautions to ensure that the generated solar power is sufficient for your household needs \n\nwe are always here to help you optimize your solar power usage and to ensure that you are getting the most out of your investment if you have any questions or concerns please do not hesitate to reach out to us\n\nbest regards\n\ntenergito',
#  'dear diana\n\ni hope this message finds you well as your solar power provider i am pleased to provide you with a small report regarding the predicted solar power generated by your solar panels on june 5th 2024 at 1 oclock in the afternoon\n\nbased on the weather forecast the predicted solar power generated will be medium approximately 6286 kilo watts this is due to the impact of hourly precipitation and temperature both of which have a negative effect on solar power generation\n\nplease note that during this time you should be able to use your air conditioner and heater without exceeding the generated power however your dishwasher may exceed the generated power so please use this appliance with caution\n\nfinally we recommend that you avoid using your washing machine during this time as it is likely to exceed the generated power\n\nthank you for choosing us as your solar power provider if you have any further questions or concerns please do not hesitate to contact us\n\nbest regards\n\ntenergito',
#  'solar power prediction report  august 22 2023 at 1100 am\n\nhello ana\n\naccording to the predicted solar radiation values we are pleased to inform you that the solar power generation from your solar panels on august 22 2023 at 1100 am is expected to be very high at 130 kilo watts this is due to a significant positive contribution from the solar radiation predicted value\n\nyou can now use your heaters without worrying about exceeding the generated power which is excellent news for you\n\nwe will continue to monitor and provide updates on the solar power generation from your solar panels regularly\n\nfeel free to get in touch if you have any questions\n\nbest regards\ntenergito',
#  'dear ana\n\ni hope this message finds you well i have generated a small report on the predicted solar power generation for august 30th 2023 at 7 oclock from your solar panels\n\nunfortunately the solar radiation predicted value for that time slot is expected to have a negative impact along with significant hourly precipitation predicted value these factors are expected to contribute to low solar power generated estimated at 112 kilo watts\n\ni wanted to bring to your attention that your washing machine may exceed the generated power during this time slot additionally your water heater and dishwasher are expected to exceed the generated power\n\nplease do not hesitate to contact me if you have any further questions or concerns i am always here to assist you in any way i can\n\nbest regards\n\ntenergito',
#  'dear diana\n\nwe hope this message finds you well we wanted to share with you the solar power predictions generated from your solar panels on august 26th 2024 at 1400 the predicted solar power generated for your home is 12286 kilo watts which is considered very high due to the positive impact of solar radiation predicted value and temperature predicted value\n\nyou can utilize this generated power for various appliances such as the heater air conditioner and water heater since it is enough to power these appliances without exceeding the generated power\n\nwe hope this report helps you understand the solar power prediction and how you can make the most out of it if you have any questions or concerns please do not hesitate to reach out to us\n\nthank you for trusting us as your solar panel provider\n\nbest regards \n\ntenergito',
#  'certainly here is a small report for your client ana\n\ndear ana\n\ni hope this message finds you well as your solar power consultant i am pleased to provide you with the following report regarding the predicted solar power generation from your solar panels on september 10th 2024 at 13 oclock\n\nduring this time frame your solar panels are expected to generate a high amount of power  312 kilo watts this increase in power can be attributed to the positive contributions from the temperature and dewpoint predictions\n\nhowever it is important to note that your appliances heater may cause an exceedance of the generated power additionally your appliances dishwasher is predicted to definitely exceed the generated power\n\ni recommend monitoring your energy usage during this time and considering adjusting your appliance usage to optimize your energy consumption\n\nplease do not hesitate to contact me if you have any questions or concerns thank you for entrusting me to provide you with solar power solutions\n\nbest regards\n\ntenergito',
#  'report for solar power generated on december 22nd 2023 at 1500\n\ndear ricardo\n\naccording to our solar power prediction system we expect your solar panels to generate a very high amount of energy on december 22nd 2023 at 1500 the predicted solar power generation is 384 kilo watts\n\nour system takes into consideration various factors that influence the amount of energy that your solar panels can generate in this case the temperature predicted value has a positive contribution to the energy production\n\nwe are pleased to inform you that you can use your dishwasher and water heater during this period since the generated power wont surpass the demand\n\nthank you for choosing us as your solar power provider if you have any questions please dont hesitate to contact us\n\nbest regards\ntenergito',
#  'dear ana\n\ni hope this message finds you well i am writing to provide you with a brief report on the predicted solar power generation for your solar panels on october 1st 2023 at 2000\n\nbased on our analysis of the predicted solar radiation values for that day we anticipate that the solar power generated by your panels will be very low amounting to only 0571 kilowatts unfortunately this means that the power generated will not be sufficient to meet the energy requirements of your washing machine and air conditioner\n\nto ensure that your household appliances are powered effectively during this time we recommend using battery storage or reducing your energy consumption during periods of low solar power generation\n\nif you have any further questions or concerns regarding this report please do not hesitate to contact me thank you for your continued partnership\n\nbest regards\n\ntenergito',
#  'dear carlos\n\nwe are pleased to inform you of the predicted solar power generation from your solar panels on january 15th 2023 at 1500 hours based on our analysis the solar power generated is estimated to be medium with an output of 176 kilo watts\n\nthis prediction is due to the negative impact of the temperature predicted value and the hourly precipitation predicted value on the solar panels power output we advise that you make use of the air conditioner since it wont surpass the generated power however we would not recommend the use of the washing machine and water heater as they will definitely exceed the generated power\n\nplease let us know if you have any questions or concerns regarding this information\n\nbest regards\n\ntenergito',
#  'dear ana\n\ni hope this message finds you well as your solar power provider i am pleased to inform you of the predicted solar power generation from your solar panels for february 5th 2023 at 1000 am\n\nbased on our calculations we expect the solar power generation to be very high at 120 kilo watts this is due to the predicted temperature value contributing positively and the predicted solar radiation value having a significant positive impact\n\nyou can use your dishwasher and water heater during this period without exceeding the generated power however please note that if you plan on using your washing machine it might exceed the generated power\n\nwe hope that this information is helpful for your energy planning and management if you have any questions please dont hesitate to contact us\n\nbest regards\ntenergito',
#  'dear ema\n\ni hope this email finds you well as your solar power provider i am pleased to inform you about the predicted solar power generation for april 4th 2023 at 14 oclock\n\nthe solar power generated from your solar panels is estimated to be high at 292 kilo watts the reason for this is due to the positive contributions of the dew point predicted value and the solar radiation predicted value\n\nbased on this prediction you can use your dishwasher and washing machine without exceeding the generated power however it is important to note that your air conditioner will definitely exceed the generated power and therefore we recommend limiting its usage during this timeframe\n\nwe hope this information helps you in planning your energy usage efficiently please feel free to contact us if you have any further questions or concerns\n\nbest regards\n\ntenergito',
#  'dear carlos\n\ni hope this message finds you well as your solar power service provider i wanted to provide you with a report on the predicted solar power generation for your solar panels on april 11th 2023 at 11 oclock\n\nthe predicted solar power generation for this time is medium estimated at 188 kilo watts this is due to the negative impact of both the temperature predictions and hourly precipitation predictions\n\non the bright side you will still be able to use your air conditioner and water heater without exceeding the generated power however its recommended to avoid using your dishwasher as it might exceed the generated power\n\nunfortunately your washing machine will definitely exceed the generated power so its best to avoid running it during this time\n\nwe hope you find this report helpful and informative as always if you have any questions or concerns please dont hesitate to reach out to our team\n\nbest regards\ntenergito',
#  'dear ana\n\nwe have generated a report for you regarding the predicted solar power generation from your solar panels on august 19th 2023 at 600 pm\n\nbased on the data we have collected we have found that the solar power generated will be low estimated at around 14 kilowatts this is due to the predicted value of solar radiation having a negative impact along with a significant negative impact from hourly precipitation\n\nwe advise that you can use the heater as it will not surpass the generated power however it is important to note that the appliances washing machine might exceed the generated power as for the appliances water heater and air conditioner they will definitely exceed the generated power and should not be used during this time\n\nwe hope this information is helpful for you to make informed decisions regarding your energy usage\n\nsincerely\n\ntenergito',
#  'dear ana\n\nwe are pleased to inform you that on october 9th 2023 at 1500 your solar panels are predicted to generate a high amount of power reaching 9143 kilo watts this is due to positive contributions from both temperature and solar radiation predictions\n\nwe would like to advise you that during this time you will be able to use your washing machine heater and dishwasher without exceeding the generated power however we suggest caution when using your appliances water heater as it may exceed the generated power\n\nwe regret to inform you that your appliances air conditioner will definitely exceed the generated power during this period we recommend using alternative forms of cooling or powering down the appliance during peak solar times\n\nthank you for choosing our solar panel services and we hope that this report will assist you in optimizing your energy usage\n\nbest regards\n\ntenergito',
#  'dear diana\n\nwe are pleased to inform you that on april 4th 2023 at 300 pm your solar panels are predicted to generate high solar power of 4067 kilo watts the positive contribution is due to the temperature being higher on that day\n\nthis means that you can use your heater without worrying about exceeding the generated power kindly note that the solar power generated may vary depending on weather conditions and other factors\n\nwe hope that this report will be helpful to you please do not hesitate to contact us if you have any questions or concerns\n\nbest regards\ntenergito team',
#  'dear toms\n\nwe wanted to share with you some exciting news about your solar panels on september 15th 2024 at 1 oclock we predict that your panels will generate an impressive 368 kilo watts of power this is due to the positive contributions from both temperature and solar radiation predicted values\n\nwith this level of energy generation you will be able to utilize your air conditioner washing machine and heater without exceeding the available power however we do recommend keeping an eye on your dishwasher usage as it may exceed the generated power\n\nwe hope this information is helpful and we look forward to continuing our work with you to maximize the benefits of your solar panels\n\nbest regards\n\ntenergito',
#  'dear carlos\n\nwe hope this message finds you well as your solar power monitoring system we wanted to provide you with a small report on your solar power generation for september 29th 2024 at 2000\n\nunfortunately based on the solar radiation predicted value for that day we anticipate a very low solar power generation of 004 kilo watts this means that it is possible that your air conditioner may exceed the generated power and your heater dishwasher and washing machine will definitely exceed the generated power\n\nit is important to note that this low solar power generation is due to external factors outside of our control we recommend that you try to limit the use of highenergy appliances during this time to minimize any potential power outages\n\nplease let us know if you have any questions or concerns regarding this report we are always here to help you maximize your solar power generation\n\nbest regards\ntenergito ai',
# ...
#  'report for client pedro\n\ndate april 20th 2023\ntime 1500 \n\nsolar power prediction medium 34 kw\n\nfactors affecting prediction\n hourly precipitation predicted value negative impact\n humidity predicted value negative impact \n\nrecommendations\n you can use the water heater since it wont surpass the generated power \n however we suggest not using the washing machine and dishwasher during this time as they will definitely exceed the generated power\n\nthank you for trusting us with your solar power needs please contact us if you have any further questions or concerns',
#  'dear ema\n\ni hope this email finds you well as your solar power advisor i am pleased to provide you with a report on the solar power generated by your solar panels on february 25th 2024 at 10 oclock\n\nthe solar radiation predicted value and temperature predicted value both show a positive contribution to the solar power generated resulting in a high output of 268 kilo watts this amount of energy is sufficient to power your heater and washing machine without exceeding the generated power\n\nhowever it is important to note that the dishwasher may exceed the generated power which means it is recommended to be cautious when using the appliance during this time\n\nplease let me know if you have any further questions or concerns it is always a pleasure to serve you and help you make the most out of your solar panels\n\nbest regards\n\ntenergito',
#  'dear diana\n\ni hope this message finds you well as your solar energy provider i wanted to share some insights with you regarding the solar power generation predicted for february 19th 2023 at 7 oclock\n\nbased on our calculations we anticipate that the solar radiation levels will be low resulting in a solar power generation of only 064 kilo watts at that time unfortunately this is not a sufficient amount of power to support some of the appliances in your home\n\nmore specifically the dishwasher might exceed the generated power and would need to be powered by grid electricity instead similarly the washing machine will definitely consume more power than the solar panels can generate making it necessary to use grid electricity for that as well\n\nwe understand that this might be disappointing but we want to remind you that solar power generation is influenced by weather patterns and other variables that are outside of our control however we remain committed to working with you to ensure that you are getting the most out of your solar panels\n\nplease dont hesitate to contact us if you have any questions or concerns we value your business and appreciate your support for renewable energy\n\nbest regards\n\ntenergito',
#  'dear rafael\n\ni hope this message finds you well as you know ive been keeping a close eye on the solar power generated by your solar panels and i wanted to provide you with some updated information regarding the upcoming days\n\non september 8th 2024 at 11 oclock were anticipating high solar power generation of 9429 kilowatts this is due in part to the positive contribution of the predicted temperature value with this amount of power generation you should be able to comfortably use your dishwasher heater and water heater without exceeding the solar power available\n\nhowever its important to note that your air conditioner may exceed the generated power if you plan on using this appliance during this period it may be wise to monitor the power usage to ensure that you dont exceed the available power\n\nplease dont hesitate to reach out with any questions or concerns im always here to help\n\nbest regards\ntenergito',
#  'dear diana\n\ni hope this message finds you well as your solar energy consultant i am pleased to inform you that on march 4th 2024 at 1800 your solar panels will be generating high power output of 46 kilo watts this is due to the positive contribution of the solar radiation predicted value\n\nas a result you can use your dishwasher and water heater without exceeding the generated power from your solar panels this means that you can enjoy the benefits of clean renewable energy while doing your daily chores\n\nplease let me know if you have any questions or concerns about your solar power system i am always here to help you optimize your renewable energy usage\n\nbest regards\ntenergito',
#  'report date october 20th 2023 \n\nreport time 1700 \n\nsolar power generated 4533 kilo watts \n\ntemperature contribution positive \n\nappliances prediction\n\n air conditioner can be used without exceeding generated power \n water heater will exceed generated power limit \n\nplease note that the solar power prediction is based on current weather forecasts and other factors may impact the actual power generated however this report can provide an estimate for planning purposes',
#  'dear carlos\n\nwe hope this message finds you well as your solar power provider we would like to inform you about the predicted solar power generation for february 7th 2024 at 13oclock\n\nour systems have projected a very high solar power generation of 6333 kilo watts for this particular day and time this is due to the temperature predicted value having a positive contribution to the solar power generation\n\nyou can take advantage of this high solar power generation by using your heater washing machine and air conditioner since they will not exceed the generated power however we advise that you refrain from using your dishwasher as it might exceed the generated power\n\nwe hope this information will be useful to you in planning your daily activities if you have any questions or concerns please do not hesitate to contact us\n\nbest regards\ntenergito',
#  'dear ema\n\ni am delighted to report to you that on december 27th 2023 at 12 oclock your solar panels are expected to generate high power output with a predicted value of 12857 kilo watts this will occur due to the positive contribution of the temperature predicted value\n\ngiven the high amount of generated solar power you are able to use certain appliances without exceeding the generated power these appliances include your water heater dishwasher washing machine and heater\n\nhowever we recommend that you do not use the air conditioner as it may exceed the generated power we encourage you to use the generated solar power as much as possible to enhance your energy efficiency and save on energy costs\n\nthank you for choosing us as your solar power provider we look forward to continually providing you with the best solar services\n\nbest regards\n\ntenergito',
#  'dear diana\n\nwe hope this letter finds you well as you know we have been monitoring the solar power generated by your solar panels and we would like to provide you with an update\n\nas of june 26th 2023 at 12 oclock the solar power generated by your solar panels is predicted to be at an alltime high reaching 6533 kilo watts this is due to the positive contribution of solar radiation and temperature predicted values\n\nwe are glad to report that you can freely use your air conditioner heater and water heater since these appliances wont surpass the generated power however we advise you to avoid using your washing machine during this time as it might exceed the generated power\n\nwe hope this information is helpful and we will keep you updated on any changes in the predicted solar power generated by your solar panels\n\nbest regards\ntenergito',
#  'dear ana\n\nwe hope you are enjoying the benefits of your solar panels we wanted to provide you with an update on the predicted solar power generation for may 29th 2024 at 2000\n\nunfortunately we anticipate lower than average solar power generation due to daily rain resulting in a predicted output of only 012 kilo watts while this may not be ideal we want to remind you that solar power generation is dependent on weather conditions\n\nit is important to note that your washing machine may exceed the amount of power generated during this time however your water heater dishwasher air conditioner and heater will definitely exceed the generated power we recommend using these appliances during times of higher solar power generation to maximize the benefits of your solar panels\n\nthank you for trusting us with your solar power needs please let us know if you have any further questions or concerns\n\nbest regards\ntenergito',
#  'dear ema\n\ni am writing to you today with regards to the solar power generated by your solar panels on october 22nd 2024 at 19 oclock unfortunately i have to report that due to the predicted hourly precipitation the solar power generated will be very low at only 1857 kilo watts\n\nthe impact of this on your home appliances will be significant specifically your air conditioner water heater washing machine and heater will all exceed the generated power this means that you may need to adjust your energy usage during this period and rely on alternative sources of energy in order to keep your appliances functioning correctly\n\ni understand that this news may be disappointing but please rest assured that we will continue to monitor the situation closely and keep you informed of any further developments if you have any questions or concerns in the meantime please do not hesitate to contact me\n\nbest regards\n\ntenergito',
#  'dear rafael\n\ni hope this message finds you well as your solar power expert i have generated a report to provide you with information about the solar power predictions from your solar panels on november 12nd 2023 at 9 oclock\n\nbased on the data available it is predicted that the solar power generated will be medium specifically 236 kilo watts the daily rain predicted value and hourly precipitation predicted value are expected to have a negative impact on the solar power generation\n\nunfortunately it is likely that your air conditioner may exceed the generated power additionally your water heater and washing machine are expected to exceed the generated power\n\nplease let me know if you have any questions or concerns regarding this report thank you for choosing our services for your solar power needs\n\nsincerely\n\ntenergito',
#  'dear ema\n\ni hope this message finds you well as your solar power advisor i wanted to provide you with some important information regarding your solar panel generator\n\non december 15th 2024 at 5 pm we predict that the solar power generated from your solar panels will be relatively low at 2133 kilo watts this is due to the fact that daily rain and solar radiation are both predicted to have a negative impact on the power generated\n\nwhile this may limit your use of certain appliances your washing machine should be safe to use and will not surpass the generated power however we recommend avoiding the use of your appliance heater as it will likely exceed the generated power\n\nwe hope this information is helpful to you and we look forward to continuing to serve as your solar power advisor if you have any further questions or concerns please do not hesitate to reach out to us\n\nbest regards\ntenergito',
#  'dear rafael\n\ni hope this letter finds you well as your solar power prediction analyst im excited to share with you some insights about the expected solar power generation from your solar panels\n\non september 28th 2023 at 1600 we anticipate that your solar panels will generate a high output of 292 kilowatts this is a result of the positive contributions of both the dewpoint predicted value and the temperature predicted value\n\nbased on this prediction we suggest that you can safely use your dishwasher and washing machine without exceeding the generated power however please note that any appliance heater might exceed the generated power\n\nwe hope that you find this information helpful and we look forward to working with you on your solar power generation in the future\n\nsincerely\n\ntenergito',
#  'dear ema\n\ni have generated a small report for you regarding the predicted solar power generation from your solar panels on december 10th 2023 at 1 pm \n\naccording to our predictions your solar panels will generate a high amount of power at this time specifically 276 kilo watts this is due to the positive contribution from the predicted dewpoint value\n\nhowever its important to note that the predicted power generated may not be sufficient to power your air conditioner we recommend taking precautions to ensure that your energy usage does not exceed the generated power \n\nplease let us know if you have any questions or concerns regarding this report or your solar power generation\n\nbest regards \ntenergito',
#  'report for rafael  solar power predictions for january 10th 2024 at 11 am\n\ndear rafael\n\nwe hope you are doing well we are pleased to provide you with the solar power predictions for january 10th 2024 at 11 oclock for your solar panels\n\nwe predict a high level of solar power generation on this day with an estimated 8857 kilo watts being generated this is due to a positive contribution from both the predicted temperature values and the predicted solar radiation values\n\nbased on these predictions we recommend that you use your heater as it wont surpass the generated power however please note that your washing machine may exceed the generated power so we advise you to use it with caution\n\nunfortunately your dishwasher will definitely exceed the generated power we recommend that you avoid using it during this time or use it sparingly if necessary\n\noverall we believe that you will be able to enjoy high levels of solar power generation on january 10th 2024 please let us know if you have any further questions\n\nthank you for choosing our services\n\nbest regards\n\ntenergito',
#  'dear constantino\n\nwe wanted to provide you with some insights on the solar power generated from your solar panels based on our predictive model on may 22nd 2024 at 12 oclock the solar power generated will be very high at 368 kilo watts\n\nthis increase in solar power generation is primarily due to the predicted temperature being higher than usual and solar radiation having a significant positive contribution this means that during this time you can use your water heater and other heaters without exceeding the generated power\n\nhowever we recommend caution when using your dishwasher as it might exceed the generated power please note that these predictions are not guaranteed as they are solely based on our model and external factors may impact the actual solar power generation\n\nplease let us know if you have any further questions or concerns regarding the solar power generated from your panels\n\nbest regards \ntenergito',
#  'dear francisco\n\nwe hope this message finds you well as your solar power provider we are happy to provide you with a report on the solar power generation for your panels on october 17th 2024 at 11 oclock \n\nbased on our predictions the solar power generation will be at a medium level generating 3067 kilo watts this is due to the negative impact of daily rain predicted for that day \n\nwe would like to inform you that your washing machine can be used without exceeding the generated power limit however we advise you to avoid using your appliance heater as it may exceed the generated power limit your air conditioner and dishwasher on the other hand will definitely exceed the generated power limit and it is recommended that you do not use them during this time\n\nwe hope you find this report helpful in managing your energy consumption efficiently if you have any further questions or concerns please do not hesitate to contact us\n\nbest regards\n\ntenergito']

# %% [markdown]
# ### Preprocess Params
# Transform the parameters in numbers

# %%
def preprocess_params(df,i):
    params = df.iloc[i]
    pre_params = []
    
    pre_params.append(datetime.strptime(params['month'],'%B').month)
    pre_params.append(float(params['day']))
    pre_params.append(int(params['year']))
    pre_params.append(int(params['hour']))
    pre_params.append(float(params['solar_power_num']))
    
    #Need to convert to right enconding
    if params['contri1'] == "positive contribution":
        pre_params.append(1)
    else:
        pre_params.append(0)
    
    return np.array(pre_params)

pre_params = np.array([preprocess_params(data, i) for i in range(len(data['day']))])

# %% [markdown]
# #### Tokenize the corpus

# %%
tokenizer = Tokenizer()
def get_sequence_of_tokens(corpus):
    ## tokenization
    tokenizer.fit_on_texts(corpus)
    total_words = len(tokenizer.word_index) + 1
    
    ## convert data to a token sequence 
    input_sequences = []
    for line in corpus:
        token_list = tokenizer.texts_to_sequences([line])[0]
        lone = []
        for i in range(1, len(token_list)):
            n_gram_sequence = token_list[:i+1]
            lone.append(n_gram_sequence)
        input_sequences.append(lone)
    return input_sequences, total_words

inp_sequences, total_words = get_sequence_of_tokens(corpus)

# %% [markdown]
# #### Pad the sequences

# %%
def generate_padded_sequences(input_sequences,total_words,params):
    max_sequence_len = max([len(x) for x in input_sequences])
    predictors = []
    labels = []
    for example in inp_sequences:
        input_sequences = np.array(pad_sequences(example, maxlen=max_sequence_len, padding='post', truncating='post'))
        predictor, label = input_sequences[:,:-1],input_sequences[:,-1]
        label = ku.to_categorical(label, num_classes=total_words)
        predictors.append(predictor)
        labels.append(label)
    
    #predictors = np.array(predictors)
    #labels = np.array(labels)
    return predictors, labels, max_sequence_len

predictors, label, max_sequence_len = generate_padded_sequences(inp_sequences,total_words,pre_params)

# %%
for i in range(len(predictors)):
    predictors[i]= predictors[i].tolist()
    predictors[i].append(pre_params[i])

# %% [markdown]
# ### Create Model

# %%
def create_model(max_sequence_len, total_words):
    input_len = max_sequence_len - 1
    input_text = Input(shape=(input_len,))
    
    # Define the embedding layer for the text input
    x = Embedding(total_words, 10, input_length=input_len)(input_text)

    # Define the LSTM layer
    x = LSTM(100)(x)
    x = Dropout(0.1)(x)

    # Define the output layer
    output = Dense(total_words, activation='softmax')(x)

    # Define the model
    model = Model(inputs=input_text, outputs=output)

    # Compile the model
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    return model

# %%
def create_model_params(max_sequence_len, total_words, num_params):
    input_len = max_sequence_len - 1
    input_text = Input(shape=(input_len,))
    input_params = Input(shape=(num_params,))
    # Define the embedding layer for the text input
    embedding = Embedding(total_words, 10, input_length=input_len)(input_text)

    # Define the LSTM layer
    lstm = LSTM(100)(embedding)
    dropout = Dropout(0.1)(lstm)

    # Concatenate the LSTM output with the input parameters
    concat = Concatenate()([dropout, input_params])

    # Define the output layer
    output = Dense(total_words, activation='softmax')(concat)

    # Define the model
    model = Model(inputs=[input_text, input_params], outputs=output)

    # Compile the model
    model.compile(loss='categorical_crossentropy', optimizer='adam')

    return model

# %%
model = create_model_params(max_sequence_len, total_words, 6)
model.summary()

test_scores = model.fit([predictors, pre_params], label, epochs=50, verbose = 1)
print(test_scores)
# Out:
# 2023-04-11 18:31:17.642401: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 18:31:17.677073: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 18:31:17.677619: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 18:31:17.678602: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-11 18:31:17.680200: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 18:31:17.680723: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 18:31:17.681619: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 18:31:18.837291: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 18:31:18.838014: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 18:31:18.838276: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-04-11 18:31:18.838604: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2619 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650 with Max-Q Design, pci bus id: 0000:02:00.0, compute capability: 7.5
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 244)]        0           []
#
#  embedding (Embedding)          (None, 244, 10)      11230       ['input_1[0][0]']
#
#  lstm (LSTM)                    (None, 100)          44400       ['embedding[0][0]']
#
#  dropout (Dropout)              (None, 100)          0           ['lstm[0][0]']
#
#  input_2 (InputLayer)           [(None, 6)]          0           []
#
#  concatenate (Concatenate)      (None, 106)          0           ['dropout[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense (Dense)                  (None, 1123)         120161      ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 175,791
# Trainable params: 175,791
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 4
#       1 model = create_model_params(max_sequence_len, total_words, 6)
#       2 model.summary()
# ----> 4 test_scores = model.fit([predictors, pre_params], label, epochs=50, verbose = 1)
#       5 print(test_scores)
#
# File ~/miniconda3/envs/meia/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/meia/lib/python3.10/site-packages/keras/engine/data_adapter.py:1081, in select_data_adapter(x, y)
#    1078 adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#    1079 if not adapter_cls:
#    1080     # TODO(scottzhu): This should be a less implementation-specific error.
# -> 1081     raise ValueError(
#    1082         "Failed to find data adapter that can handle input: {}, {}".format(
#    1083             _type_name(x), _type_name(y)
#    1084         )
#    1085     )
#    1086 elif len(adapter_cls) > 1:
#    1087     raise RuntimeError(
#    1088         "Data adapters should be mutually exclusive for "
#    1089         "handling inputs. Found multiple adapters {} to handle "
#    1090         "input: {}, {}".format(adapter_cls, _type_name(x), _type_name(y))
#    1091     )
#
# ValueError: Failed to find data adapter that can handle input: (<class 'list'> containing values of types {'(<class \'list\'> containing values of types {\'(<class \\\'list\\\'> containing values of types {\\\'(<class \\\\\\\'list\\\\\\\'> containing values of types {"<class \\\\\\\'int\\\\\\\'>"})\\\', "<class \\\'numpy.ndarray\\\'>"})\'})', "<class 'numpy.ndarray'>"}), (<class 'list'> containing values of types {"<class 'numpy.ndarray'>"})

# %% [markdown]
# ### Serialize Model

# %%
with open('nlp_model.pkl', 'wb') as f:
    pickle.dump(model, f)
    f.close()
    
with open('max_sequence_len.pkl', 'wb') as f:
    pickle.dump(max_sequence_len, f)
    f.close()

# %% [markdown]
# ### Load Model

# %%
with open('nlp_model.pkl', 'rb') as f:
    model = pickle.load(f)

with open('max_sequence_len.pkl', 'rb') as f:
    max_sequence_len = pickle.load(f)

# %% [markdown]
# ### Generate Text

# %%
def generate_text(seed_text, next_words, model, max_sequence_len):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        predicted = model.predict(token_list, verbose=0)
        predicted=np.argmax(predicted,axis=1)
        
        output_word = ""
        for word,index in tokenizer.word_index.items():
            if predicted == index:
                output_word = word
                break
        seed_text += " "+output_word
    return seed_text.title()

# %%
def generate_text_params(model, tokenizer, max_sequence_len, seed_text, num_gen_words, params):
    # Preprocess the parameters
    params = preprocess_params(params)
    # Generate words one by one
    generated = ""
    for i in range(num_gen_words):
        # Tokenize the seed text
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        # Pad the tokenized sequence to the desired length
        token_list = pad_sequences([token_list], maxlen=max_sequence_len-1, padding='pre')
        # Convert the parameters to a numpy array
        params_arr = np.array([params])
        # Generate the next word using the model and parameters
        probs = model.predict([token_list, params_arr])[0]
        y_pred = np.random.choice(range(1, total_words), p=probs)
        # Convert the predicted word back to a string
        output_word = ""
        for word, index in tokenizer.word_index.items():
            if index == y_pred:
                output_word = word
                break
        # Append the predicted word to the generated text
        generated += " " + output_word
        # Update the seed text with the predicted word
        seed_text += " " + output_word
    return generated.strip()

# %%
print(generate_text("hourly precipitation", 200, model, max_sequence_len))
